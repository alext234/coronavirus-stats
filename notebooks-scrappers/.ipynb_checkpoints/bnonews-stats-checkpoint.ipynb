# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
chrome_options = Options()  
chrome_options.add_argument("--headless")  
chrome_options.add_argument("--no-sandbox")

driver = webdriver.Chrome('chromedriver', options=chrome_options)

# %%
# url = 'https://bnonews.com/index.php/2020/02/the-latest-coronavirus-cases/'
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vR30F8lYP3jG7YOq8es0PBpJIE5yvRVZffOyaqC0GgMBN6yt0Q-NI8pxS7hd1F9dYXnowSC6zpZmW9D/pubhtml'
driver.get(url)
content = driver.page_source

# %% [markdown]
# ### Extract date time

# %%
# soup =BeautifulSoup(content, 'lxml')

# %%
# data = soup.findAll(text=re.compile("Last update: .+"))
# data

# %%
# m = re.search("Last update: (\d+ \w+ 202\d) at (\d+:\d+ [apAP].*[mM])", data[0])
# data_date_time = ' '.join([m.group(1), m.group(2)])
# data_date_time = re.sub("[\.]","",data_date_time)
# data_date_time = datetime.strptime(data_date_time, '%d %B %Y %I:%M %p').strftime('%Y-%m-%d %H:%M')
# data_date_time
data_date_time = datetime.now().strftime('%Y-%m-%d %H:%M')
data_date_time
# Out:
# '2020-03-20 10:16'

# %% [markdown]
# ### Dataframes

# %%
dfs = pd.read_html(content)

# %%
len(dfs)
dfs[0]
# Out:
#      Unnamed: 0    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0             1           NaN        NaN        NaN        NaN         NaN
# 1             2           NaN        NaN        NaN        NaN         NaN
# 2             3         CASES     DEATHS  RECOVERED  RECOVERED  UNRESOLVED
# 3             4        247717      10179      86079      86079      151459
# 4             5           NaN        NaN        NaN        NaN         NaN
# ..          ...           ...        ...        ...        ...         ...
# 176         177         Nepal          1          0          0           0
# 177         178  Vatican City          1          0          0           0
# 178         179         Queue       3030       -100        153           0
# 179         180         TOTAL     247717        872      10179           9
# 180         181           NaN      Cases  New cases     Deaths  New deaths
#
#       Unnamed: 6          Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  \
# 0            NaN                 NaN        NaN        NaN          NaN
# 1            NaN                 NaN        NaN        NaN          NaN
# 2     UNRESOLVED          UNRESOLVED        NaN        NaN          NaN
# 3            NaN                 NaN        NaN        NaN          NaN
# 4            NaN                 NaN        NaN        NaN          NaN
# ..           ...                 ...        ...        ...          ...
# 176        0.00%                 NaN          1     Source          NaN
# 177        0.00%                 NaN        NaN     Source          NaN
# 178          NaN                 NaN        NaN        NaN          NaN
# 179        4.11%                7235      86079        NaN          NaN
# 180  % of deaths  Serious & Critical  Recovered        NaN          NaN
#
#      Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ..           ...         ...         ...
# 176          NaN           1           0
# 177          NaN           1           0
# 178          NaN        3130         153
# 179          NaN      246735       10179
# 180          NaN         NaN         NaN
#
# [181 rows x 14 columns]

# %% [markdown]
# ### International

# %%
df_intl=dfs[0]
df_intl  = df_intl.drop(df_intl .columns[0], axis=1)
df_intl  = df_intl.drop(list(range(6)), axis=0)
num_cols = len(df_intl.columns)
columns = ['d'] * num_cols
columns[0]='international'
columns[1]='cases'
df_intl.columns=columns
df_intl
# Out:
#     international   cases          d       d           d            d  \
# 6           China   80967         39    3248           3        4.01%
# 7           Italy   41035          0    3405           0        8.30%
# 8            Iran   18407          0    1284           0        6.98%
# 9           Spain   18077          0     833           0        4.61%
# 10        Germany   15320          0      44           0        0.29%
# ..            ...     ...        ...     ...         ...          ...
# 176         Nepal       1          0       0           0        0.00%
# 177  Vatican City       1          0       0           0        0.00%
# 178         Queue    3030       -100     153           0          NaN
# 179         TOTAL  247717        872   10179           9        4.11%
# 180           NaN   Cases  New cases  Deaths  New deaths  % of deaths
#
#                       d          d       d   d   d       d      d
# 6                  2314      70420  Source NaN NaN   80928   3245
# 7                  2498       4440  Source NaN NaN   41035   3405
# 8                   NaN       5979  Source NaN NaN   18407   1284
# 9                   939       1107  Source NaN NaN   18077    833
# 10                    2        115  Source NaN NaN   15320     44
# ..                  ...        ...     ...  ..  ..     ...    ...
# 176                 NaN          1  Source NaN NaN       1      0
# 177                 NaN        NaN  Source NaN NaN       1      0
# 178                 NaN        NaN     NaN NaN NaN    3130    153
# 179                7235      86079     NaN NaN NaN  246735  10179
# 180  Serious & Critical  Recovered     NaN NaN NaN     NaN    NaN
#
# [175 rows x 13 columns]

# %%
df_intl.columns = df_intl.columns.map(str.lower)
df_intl = df_intl.dropna(0, how='all')

# %% [markdown]
# #### Cases

# %%
df_intl_cases = df_intl[['international', 'cases']].set_index('international').T
df_intl_cases.drop(columns = ['China', 'Queue', 'TOTAL'], inplace=True)
df_intl_cases
# Out:
# international  Italy   Iran  Spain Germany United States France South Korea  \
# cases          41035  18407  18077   15320         14312  10995        8652
#
# international Switzerland United Kingdom Netherlands  ... Antigua and Barbuda  \
# cases                4164           3269        2460  ...                   1
#
# international Sudan Montserrat Gambia Eswatini Somalia  \
# cases             1          1      1        1       1
#
# international Central African Republic Nepal Vatican City    NaN
# cases                                1     1            1  Cases
#
# [1 rows x 172 columns]

# %%
na_columns = df_intl_cases.columns[df_intl_cases.columns.isna()]
df_intl_cases.drop(columns=na_columns, inplace=True)

# %%
df_intl_cases = df_intl_cases.apply(lambda row: 
                   [re.sub('[^\d]+', '', x)  for x in row ])
df_intl_cases = df_intl_cases.apply(lambda row: 
                   [int(x) if x!='' else 0  for x in row ])

# %%
df_intl_cases
# Out:
# international  Italy   Iran  Spain  Germany  United States  France  \
# cases          41035  18407  18077    15320          14312   10995
#
# international  South Korea  Switzerland  United Kingdom  Netherlands  ...  \
# cases                 8652         4164            3269         2460  ...
#
# international  Djibouti  Antigua and Barbuda  Sudan  Montserrat  Gambia  \
# cases                 1                    1      1           1       1
#
# international  Eswatini  Somalia  Central African Republic  Nepal  \
# cases                 1        1                         1      1
#
# international  Vatican City
# cases                     1
#
# [1 rows x 171 columns]

# %%
# add date time column
df_intl_cases.insert(0, 'datetime', data_date_time)
df_intl_cases
# Out:
# international          datetime  Italy   Iran  Spain  Germany  United States  \
# cases          2020-03-20 10:16  41035  18407  18077    15320          14312
#
# international  France  South Korea  Switzerland  United Kingdom  ...  \
# cases           10995         8652         4164            3269  ...
#
# international  Djibouti  Antigua and Barbuda  Sudan  Montserrat  Gambia  \
# cases                 1                    1      1           1       1
#
# international  Eswatini  Somalia  Central African Republic  Nepal  \
# cases                 1        1                         1      1
#
# international  Vatican City
# cases                     1
#
# [1 rows x 172 columns]

# %%
# some assertion to ensure data quality
assert int(df_intl_cases['South Korea'])>6000

# %% [markdown]
# #### Save to file

# %%
from pathlib import Path
csv_file = '../data/bnonews-international.csv'

df = df_intl_cases

if Path(csv_file).exists():
    old_df = pd.read_csv(csv_file, parse_dates=True)

# %%
# unnamed_cols = old_df.columns[old_df.columns.str.startswith('Unnamed')]
# old_df.drop(columns=unnamed_cols, inplace=True)

# %%
df = pd.concat([old_df, df], sort=True)
df = df.set_index('datetime').fillna(0)

# %%
df = df.loc[~df.index.duplicated(keep='first')]
df.sort_values(by=['datetime'], inplace=True)


for col in df.columns:
    df[col] = df[col].astype('int')
    
df
# Out:
#                   Afghanistan  Albania  Algeria  Andorra  Antigua and Barbuda  \
# datetime
# 2020-02-06 08:03            0        0        0        0                    0
# 2020-02-06 08:19            0        0        0        0                    0
# 2020-02-06 09:01            0        0        0        0                    0
# 2020-02-06 09:46            0        0        0        0                    0
# 2020-02-06 17:56            0        0        0        0                    0
# ...                       ...      ...      ...      ...                  ...
# 2020-03-20 07:08           22       59       82       53                    1
# 2020-03-20 08:08           22       59       82       53                    1
# 2020-03-20 09:08           22       59       82       53                    1
# 2020-03-20 10:02           22       59       82       53                    1
# 2020-03-20 10:16           22       59       82       53                    1
#
#                   Argentina  Armenia  Aruba  Australia  Austria  ...  \
# datetime                                                         ...
# 2020-02-06 08:03          0        0      0         15        0  ...
# 2020-02-06 08:19          0        0      0         15        0  ...
# 2020-02-06 09:01          0        0      0         15        0  ...
# 2020-02-06 09:46          0        0      0         15        0  ...
# 2020-02-06 17:56          0        0      0         15        0  ...
# ...                     ...      ...    ...        ...      ...  ...
# 2020-03-20 07:08         97      115      4        799     2013  ...
# 2020-03-20 08:08         97      115      4        800     2013  ...
# 2020-03-20 09:08         97      115      4        800     2203  ...
# 2020-03-20 10:02         97      115      5        800     2203  ...
# 2020-03-20 10:16         97      115      5        800     2203  ...
#
#                   United Arab Emirates  United Kingdom  United States  \
# datetime
# 2020-02-06 08:03                     0               2             12
# 2020-02-06 08:19                     0               3             12
# 2020-02-06 09:01                     0               3             12
# 2020-02-06 09:46                     0               3             12
# 2020-02-06 17:56                     0               3             12
# ...                                ...             ...            ...
# 2020-03-20 07:08                   113            3269          14312
# 2020-03-20 08:08                   113            3269          14312
# 2020-03-20 09:08                   113            3269          14312
# 2020-03-20 10:02                   113            3269          14312
# 2020-03-20 10:16                   113            3269          14312
#
#                   Uruguay  Uzbekistan  Vatican City  Venezuela  Vietnam  \
# datetime
# 2020-02-06 08:03        0           0             0          0       12
# 2020-02-06 08:19        0           0             0          0       12
# 2020-02-06 09:01        0           0             0          0       12
# 2020-02-06 09:46        0           0             0          0       12
# 2020-02-06 17:56        0           0             0          0       12
# ...                   ...         ...           ...        ...      ...
# 2020-03-20 07:08       79          23             1         36       76
# 2020-03-20 08:08       79          23             1         36       76
# 2020-03-20 09:08       79          33             1         36       76
# 2020-03-20 10:02       79          33             1         36       76
# 2020-03-20 10:16       79          33             1         36       76
#
#                   WORLD  Zambia
# datetime
# 2020-02-06 08:03      0       0
# 2020-02-06 08:19      0       0
# 2020-02-06 09:01      0       0
# 2020-02-06 09:46      0       0
# 2020-02-06 17:56      0       0
# ...                 ...     ...
# 2020-03-20 07:08      0       2
# 2020-03-20 08:08      0       2
# 2020-03-20 09:08      0       2
# 2020-03-20 10:02      0       2
# 2020-03-20 10:16      0       2
#
# [696 rows x 178 columns]

# %%
df.to_csv(csv_file, index=True)

# %%
import seaborn as sns

series = df.iloc[-1]

sns.set(rc={'figure.figsize':(14,28)})
ax = sns.barplot(y=series.index, x=series)
ax.set_xlabel('Number of cases, sampled at '+series.name)
# Out:
# Text(0.5, 0, 'Number of cases, sampled at 2020-03-20 10:16')

# %%
png_file='../images/bnonews-international.png'
fig = ax.get_figure()
fig.savefig(png_file)
