# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
chrome_options = Options()  
chrome_options.add_argument("--headless")  
chrome_options.add_argument("--no-sandbox")

driver = webdriver.Chrome('chromedriver', options=chrome_options)

# %%
# url = 'https://bnonews.com/index.php/2020/02/the-latest-coronavirus-cases/'
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vR30F8lYP3jG7YOq8es0PBpJIE5yvRVZffOyaqC0GgMBN6yt0Q-NI8pxS7hd1F9dYXnowSC6zpZmW9D/pubhtml'
driver.get(url)
content = driver.page_source

# %% [markdown]
# ### Extract date time

# %%
# soup =BeautifulSoup(content, 'lxml')

# %%
# data = soup.findAll(text=re.compile("Last update: .+"))
# data

# %%
# m = re.search("Last update: (\d+ \w+ 202\d) at (\d+:\d+ [apAP].*[mM])", data[0])
# data_date_time = ' '.join([m.group(1), m.group(2)])
# data_date_time = re.sub("[\.]","",data_date_time)
# data_date_time = datetime.strptime(data_date_time, '%d %B %Y %I:%M %p').strftime('%Y-%m-%d %H:%M')
# data_date_time
data_date_time = datetime.now().strftime('%Y-%m-%d %H:%M')
data_date_time
# Out:
# '2020-03-06 21:42'

# %% [markdown]
# ### Dataframes

# %%
dfs = pd.read_html(content)

# %%
len(dfs)
dfs[0]
# Out:
#     Unnamed: 0                                 Unnamed: 1 Unnamed: 2  \
# 0            1  Last update: 6 March 2020 at 4:00 p.m. ET        NaN
# 1            2                                        NaN        NaN
# 2            3                                      CASES     DEATHS
# 3            4                                     101449       3456
# 4            5                                        NaN        NaN
# ..         ...                                        ...        ...
# 95          96                               Vatican City          1
# 96          97                                   Cameroon          1
# 97          98                                   Colombia          1
# 98          99                               South Africa          1
# 99         100                                      TOTAL     101449
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8
# 0         NaN        NaN        NaN        NaN        NaN         NaN
# 1         NaN        NaN        NaN        NaN        NaN         NaN
# 2      DEATHS  RECOVERED  RECOVERED        NaN        NaN         NaN
# 3        3456      55648      55648        NaN        NaN         NaN
# 4         NaN        NaN        NaN        NaN        NaN         NaN
# ..        ...        ...        ...        ...        ...         ...
# 95          0        NaN        NaN        NaN     Source         NaN
# 96          0        NaN        NaN        NaN     Source         NaN
# 97          0        NaN        NaN        NaN     Source         NaN
# 98          0        NaN        NaN        NaN     Source         NaN
# 99       3456       6335         49      55648        NaN         NaN
#
# [100 rows x 9 columns]

# %% [markdown]
# ### International

# %%
df_intl=dfs[0]
df_intl  = df_intl.drop(df_intl .columns[0], axis=1)
df_intl  = df_intl.drop(list(range(6)), axis=0)
num_cols = len(df_intl.columns)
columns = ['d'] * num_cols
columns[0]='international'
columns[1]='cases'
df_intl.columns=columns
df_intl
# Out:
#        international   cases     d     d    d      d       d   d
# 6     Mainland China   80555  3042  5737    -  53726  Source NaN
# 7        South Korea    6593    42    27   25    108  Source NaN
# 8               Iran    4747   124     -    -    913  Source NaN
# 9              Italy    4636   197   462    -    523  Source NaN
# 10  Diamond Princess     696     6    34    -     40  Source NaN
# ..               ...     ...   ...   ...  ...    ...     ...  ..
# 95      Vatican City       1     0   NaN  NaN    NaN  Source NaN
# 96          Cameroon       1     0   NaN  NaN    NaN  Source NaN
# 97          Colombia       1     0   NaN  NaN    NaN  Source NaN
# 98      South Africa       1     0   NaN  NaN    NaN  Source NaN
# 99             TOTAL  101449  3456  6335   49  55648     NaN NaN
#
# [94 rows x 8 columns]

# %%
df_intl.columns = df_intl.columns.map(str.lower)
df_intl = df_intl.dropna(0, how='all')

# %% [markdown]
# #### Cases

# %%
df_intl_cases = df_intl[['international', 'cases']].set_index('international').T
df_intl_cases = df_intl_cases.apply(lambda row: 
                   [re.sub('[^\d]+', '', x)  for x in row ])
df_intl_cases = df_intl_cases.apply(lambda row: 
                   [int(x) if x!='' else 0  for x in row ])

# %%
df_intl_cases = df_intl_cases.drop(['TOTAL'], axis=1)

# %%
# add date time column
df_intl_cases.insert(0, 'datetime', data_date_time)
try:
    df_intl_cases.drop('Mainland China', axis=1, inplace=True)
except Exception(e):
    pass
df_intl_cases
# Out:
# international          datetime  South Korea  Iran  Italy  Diamond Princess  \
# cases          2020-03-06 21:42         6593  4747   4636               696
#
# international  Germany  France  Japan  Spain  United States  ...  \
# cases              639     613    350    296            272  ...
#
# international  Dominican Republic  Argentina  Liechtenstein  Bhutan  \
# cases                           1          1              1       1
#
# international  Gibraltar  Serbia  Vatican City  Cameroon  Colombia  \
# cases                  1       1             1         1         1
#
# international  South Africa
# cases                     1
#
# [1 rows x 93 columns]

# %%
# some assertion to ensure data quality
assert int(df_intl_cases['South Korea'])>6000

# %% [markdown]
# #### Save to file

# %%
from pathlib import Path
csv_file = 'data/bnonews-international.csv'

df = df_intl_cases

if Path(csv_file).exists():
    old_df = pd.read_csv(csv_file, parse_dates=True)

    df = pd.concat([old_df, df], sort=True)
df = df.set_index('datetime').fillna(0)

# %%
df = df.loc[~df.index.duplicated(keep='first')]
df.sort_values(by=['datetime'], inplace=True)


for col in df.columns:
    df[col] = df[col].astype('int')
    
df
# Out:
#                   Afghanistan  Algeria  Andorra  Argentina  Armenia  \
# datetime
# 2020-02-06 08:03            0        0        0          0        0
# 2020-02-06 08:19            0        0        0          0        0
# 2020-02-06 09:01            0        0        0          0        0
# 2020-02-06 09:46            0        0        0          0        0
# 2020-02-06 17:56            0        0        0          0        0
# ...                       ...      ...      ...        ...      ...
# 2020-03-06 16:12            1       17        1          1        1
# 2020-03-06 18:55            1       17        1          1        1
# 2020-03-06 19:10            1       17        1          1        1
# 2020-03-06 20:10            1       17        1          1        1
# 2020-03-06 21:11            1       17        1          1        1
#
#                   Australia  Austria  Azerbaijan  Bahrain  Belarus  ...  \
# datetime                                                            ...
# 2020-02-06 08:03         15        0           0        0        0  ...
# 2020-02-06 08:19         15        0           0        0        0  ...
# 2020-02-06 09:01         15        0           0        0        0  ...
# 2020-02-06 09:46         15        0           0        0        0  ...
# 2020-02-06 17:56         15        0           0        0        0  ...
# ...                     ...      ...         ...      ...      ...  ...
# 2020-03-06 16:12         61       47           6       49        6  ...
# 2020-03-06 18:55         61       47           6       49        6  ...
# 2020-03-06 19:10         61       47           6       49        6  ...
# 2020-03-06 20:10         61       55           6       49        6  ...
# 2020-03-06 21:11         61       55           6       49        6  ...
#
#                   Switzerland  Taiwan  Thailand  Tunisia  UAE  Ukraine  \
# datetime
# 2020-02-06 08:03            0       0        25        0    5        0
# 2020-02-06 08:19            0       0        25        0    5        0
# 2020-02-06 09:01            0       0        25        0    5        0
# 2020-02-06 09:46            0       0        25        0    5        0
# 2020-02-06 17:56            0       0        25        0    5        0
# ...                       ...     ...       ...      ...  ...      ...
# 2020-03-06 16:12           80      45        47        1   27        1
# 2020-03-06 18:55           80      45        47        1   27        1
# 2020-03-06 19:10           80      45        47        1   27        1
# 2020-03-06 20:10          210      45        47        1   27        1
# 2020-03-06 21:11          210      45        47        1   27        1
#
#                   United Kingdom  United States  Vatican City  Vietnam
# datetime
# 2020-02-06 08:03               2             12             0       12
# 2020-02-06 08:19               3             12             0       12
# 2020-02-06 09:01               3             12             0       12
# 2020-02-06 09:46               3             12             0       12
# 2020-02-06 17:56               3             12             0       12
# ...                          ...            ...           ...      ...
# 2020-03-06 16:12             116            234             1       16
# 2020-03-06 18:55             116            253             1       16
# 2020-03-06 19:10             116            259             1       16
# 2020-03-06 20:10             164            267             1       16
# 2020-03-06 21:11             164            272             1       16
#
# [382 rows x 94 columns]

# %%
df.to_csv(csv_file, index=True)

# %%
import seaborn as sns

series = df.iloc[-1]

sns.set(rc={'figure.figsize':(14,16)})
ax = sns.barplot(y=series.index, x=series)
ax.set_xlabel('Number of cases, sampled at '+series.name)
# Out:
# Text(0.5, 0, 'Number of cases, sampled at 2020-03-06 21:11')

# %%
png_file='images/bnonews-international.png'
fig = ax.get_figure()
fig.savefig(png_file)
