# %%
import sys
sys.path.append("../")

# %%
import pandas as pd
from datetime import datetime
import json
from shields import write_shields_json

# %%
# last update badge

data_date_time = datetime.now().strftime('%Y-%m-%d %H:%M')
data_date_time

write_shields_json('../data/last_update.json', label='Last update', message=data_date_time)

# %%
bno_csv = '../data/bnonews-international.csv'
df_bno = pd.read_csv(bno_csv, infer_datetime_format=True, index_col='datetime')
df_bno
# Out:
#                   Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# datetime
# 2020-02-06 08:03            0        0        0        0       0         0
# 2020-02-06 08:19            0        0        0        0       0         0
# 2020-02-06 09:01            0        0        0        0       0         0
# 2020-02-06 09:46            0        0        0        0       0         0
# 2020-02-06 17:56            0        0        0        0       0         0
# ...                       ...      ...      ...      ...     ...       ...
# 2020-04-12 23:07          607      446     1914      638      19         3
# 2020-04-13 00:10          607      446     1914      638      19         3
# 2020-04-13 01:07          607      446     1914      638      19         3
# 2020-04-13 02:08          607      446     1914      638      19         3
# 2020-04-13 03:08          607      446     1914      638      19         3
#
#                   Antigua and Barbuda  Argentina  Armenia  Aruba  ...  \
# datetime                                                          ...
# 2020-02-06 08:03                    0          0        0      0  ...
# 2020-02-06 08:19                    0          0        0      0  ...
# 2020-02-06 09:01                    0          0        0      0  ...
# 2020-02-06 09:46                    0          0        0      0  ...
# 2020-02-06 17:56                    0          0        0      0  ...
# ...                               ...        ...      ...    ...  ...
# 2020-04-12 23:07                   21       2142      977     92  ...
# 2020-04-13 00:10                   21       2142      977     92  ...
# 2020-04-13 01:07                   21       2142      977     92  ...
# 2020-04-13 02:08                   21       2142      977     92  ...
# 2020-04-13 03:08                   21       2208     1013     92  ...
#
#                   United States  Uruguay  Uzbekistan  Vatican City  Venezuela  \
# datetime
# 2020-02-06 08:03             12        0           0             0          0
# 2020-02-06 08:19             12        0           0             0          0
# 2020-02-06 09:01             12        0           0             0          0
# 2020-02-06 09:46             12        0           0             0          0
# 2020-02-06 17:56             12        0           0             0          0
# ...                         ...      ...         ...           ...        ...
# 2020-04-12 23:07         557574      501         865             8        175
# 2020-04-13 00:10         558153      501         865             8        175
# 2020-04-13 01:07         558193      501         865             8        175
# 2020-04-13 02:08         558193      501         865             8        175
# 2020-04-13 03:08         560354      480         865             8        175
#
#                   Vietnam  WORLD  Yemen  Zambia  Zimbabwe
# datetime
# 2020-02-06 08:03       12      0      0       0         0
# 2020-02-06 08:19       12      0      0       0         0
# 2020-02-06 09:01       12      0      0       0         0
# 2020-02-06 09:46       12      0      0       0         0
# 2020-02-06 17:56       12      0      0       0         0
# ...                   ...    ...    ...     ...       ...
# 2020-04-12 23:07      260      0      1      40        14
# 2020-04-13 00:10      260      0      1      40        14
# 2020-04-13 01:07      260      0      1      40        14
# 2020-04-13 02:08      262      0      1      40        14
# 2020-04-13 03:08      262      0      1      40        14
#
# [1219 rows x 212 columns]

# %%
latest = df_bno.iloc[-1]

display(latest)
# Out:
# Afghanistan     607
# Albania         446
# Algeria        1914
# Andorra         638
# Angola           19
#                ...
# Vietnam         262
# WORLD             0
# Yemen             1
# Zambia           40
# Zimbabwe         14
# Name: 2020-04-13 03:08, Length: 212, dtype: int64

# %%
timestamp = latest.name
display(timestamp)
# Out:
# '2020-04-13 03:08'

# %%
# Top 10 countries
del latest['Diamond Princess']
del latest['Queue']
top10_countries = latest.sort_values(ascending=False)[:10]
display(top10_countries)
# Out:
# United States     560354
# Spain             166831
# Italy             156363
# France            132591
# Germany           128326
# United Kingdom     84279
# Iran               71686
# Turkey             56956
# Belgium            29647
# Netherlands        25587
# Name: 2020-04-13 03:08, dtype: int64

# %%
top10_str = ' '.join([f'{country}:{cases:}' for country,cases in top10_countries.iteritems()])

display(top10_str)
# Out:
# 'United States:560354 Spain:166831 Italy:156363 France:132591 Germany:128326 United Kingdom:84279 Iran:71686 Turkey:56956 Belgium:29647 Netherlands:25587'

# %%
# output json stat 
write_shields_json('../data/top10.json', label='Top 10', message=top10_str)

# %%
# Number of cases increase from yesterday breakdown by countries?
